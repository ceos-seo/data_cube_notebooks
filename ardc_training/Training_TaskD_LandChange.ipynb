# %%
from sys import path
path.append("../")

# %% [markdown]
# # ARDC Training: Python Notebooks
# Task-D: Land Change

# %% [markdown]
# > ### Import the Datacube Configuration

# %%
import datacube
dc = datacube.Datacube(app = 'my_app', config = '/home/localuser/.datacube.conf')

# %%
# Enable plotting
# %matplotlib inline

# Supress Warning 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# >### Browse the available Data Cubes

# %%
list_of_products = dc.list_products()
netCDF_products = list_of_products[list_of_products['format'] == 'NetCDF']
netCDF_products
# Out:
#                                   name  \
# id
# 91    alos02_palsar02_scansar_colombia
# 92       alos02_palsar02_scansar_samoa
# 93     alos02_palsar02_scansar_vietnam
# 61  alos2_jjfast_scansar_tile_colombia
# 65       alos2_palsar2_scansar_caqueta
# 50               alos2_palsar_colombia
# 51                  alos2_palsar_kenya
# 52                alos2_palsar_vietnam
# 53                alos_palsar_colombia
# 54                   alos_palsar_kenya
# 55                 alos_palsar_vietnam
# 14          gpm_imerg_gis_daily_global
# 15        gpm_imerg_gis_monthly_global
# 17               ls5_ledaps_bangladesh
# 18           ls5_ledaps_lake_chad_full
# 85               ls5_ledaps_swiss_mini
# 19             ls7_ledaps_amazon_river
# 20               ls7_ledaps_bangladesh
# 35          ls7_ledaps_bangladesh_bari
# 87                  ls7_ledaps_caqueta
# 21                 ls7_ledaps_colombia
# 22                    ls7_ledaps_ghana
# 74                 ls7_ledaps_honduras
# 23                    ls7_ledaps_kenya
# 41             ls7_ledaps_lake_baringo
# 24           ls7_ledaps_lake_chad_full
# 25             ls7_ledaps_lake_cortijo
# 26           ls7_ledaps_menindee_lakes
# 27               ls7_ledaps_meta_river
# 28          ls7_ledaps_salgar_colombia
# 68                    ls7_ledaps_samoa
# 75             ls7_ledaps_south_africa
# 82               ls7_ledaps_swiss_mini
# 79              ls7_ledaps_switzerland
# 29                     ls7_ledaps_togo
# 30                    ls7_ledaps_tonga
# 31                  ls7_ledaps_vietnam
# 86                   ls8_lasrc_caqueta
# 73                  ls8_lasrc_honduras
# 32            ls8_lasrc_lake_chad_full
# 33                ls8_lasrc_meta_river
# 70                     ls8_lasrc_samoa
# 83                ls8_lasrc_swiss_mini
# 77               ls8_lasrc_switzerland
# 71                     ls8_lasrc_tonga
# 40                   ls8_lasrc_uruguay
# 34                   ls8_lasrc_vietnam
# 57                  s1_gamma0_colombia
# 58                 s1_gamma0_lake_chad
# 59            s1_gamma0_menindee_lakes
# 60                   s1_gamma0_vietnam
# 97                  s1g_gamma0_caqueta
# 99                    s1g_gamma0_samoa
# 80              s1g_gamma0_switzerland
# 89               s1yearly_gamma0_ghana
# 13     terra_aster_gdm_salgar_colombia
# 66               terra_aster_gdm_samoa
#
#                                           description instrument  \
# id
# 91  ALOS2 PALSAR JJFAST tile in DN format processe...   PALSAR-2
# 92  ALOS2 PALSAR JJFAST tile in DN format processe...   PALSAR-2
# 93  ALOS2 PALSAR JJFAST tile in DN format processe...   PALSAR-2
# 61  ALOS2 PALSAR JJFAST tile in DN format processe...     PALSAR
# 65  ALOS2 PALSAR JJFAST tile in DN format processe...   PALSAR_2
# 50  ALOS2 PALSAR tile in DN format processed for t...     PALSAR
# 51  ALOS2 PALSAR tile in DN format processed for t...     PALSAR
# 52  ALOS2 PALSAR tile in DN format processed for t...     PALSAR
# 53  ALOS PALSAR tile in DN format processed for th...     PALSAR
# 54  ALOS PALSAR tile in DN format processed for th...     PALSAR
# 55  ALOS PALSAR tile in DN format processed for th...     PALSAR
# 14                   Global NetCDF GPM IMERG GIS data        GPM
# 15                   Global NetCDF GPM IMERG GIS data        GPM
# 17  Landsat 5 USGS Collection 1 Higher Level SR sc...         TM
# 18  Landsat 5 USGS Collection 1 Higher Level SR sc...         TM
# 85  Landsat 5 USGS Collection 1 Higher Level SR sc...        TM1
# 19  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 20  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 35  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 87  Landsat 7 USGS Collection 1 Higher Level SR sc...       ETM1
# 21  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 22  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 74  Landsat 7 USGS Collection 1 Higher Level SR sc...       ETM1
# 23  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 41  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 24  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 25  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 26  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 27  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 28  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 68  Landsat 7 USGS Collection 1 Higher Level SR sc...       ETM1
# 75  Landsat 7 USGS Collection 1 Higher Level SR sc...       ETM1
# 82  Landsat 7 USGS Collection 1 Higher Level SR sc...       ETM3
# 79  Landsat 7 USGS Collection 1 Higher Level SR sc...       ETM3
# 29  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 30  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 31  Landsat 7 USGS Collection 1 Higher Level SR sc...        ETM
# 86  Landsat 8 USGS Collection 1 Higher Level SR sc...  OLI_TIRS1
# 73  Landsat 8 USGS Collection 1 Higher Level SR sc...  OLI_TIRS1
# 32  Landsat 8 USGS Collection 1 Higher Level SR sc...   OLI_TIRS
# 33  Landsat 8 USGS Collection 1 Higher Level SR sc...   OLI_TIRS
# 70  Landsat 8 USGS Collection 1 Higher Level SR sc...  OLI_TIRS1
# 83  Landsat 8 USGS Collection 1 Higher Level SR sc...  OLI_TIRS1
# 77  Landsat 8 USGS Collection 1 Higher Level SR sc...  OLI_TIRS1
# 71  Landsat 8 USGS Collection 1 Higher Level SR sc...  OLI_TIRS1
# 40  Landsat 8 USGS Collection 1 Higher Level SR sc...   OLI_TIRS
# 34  Landsat 8 USGS Collection 1 Higher Level SR sc...   OLI_TIRS
# 57  Sentinel-1A/B SAR Gamma0, processed to the CEO...        SAR
# 58  Sentinel-1A/B SAR Gamma0, processed to the CEO...        SAR
# 59  Sentinel-1A/B SAR Gamma0, processed to the CEO...        SAR
# 60  Sentinel-1A/B SAR Gamma0, processed to the CEO...        SAR
# 97  Sentinel-1A/B SAR Gamma0, processed to the GEE...        SAR
# 99  Sentinel-1A/B SAR Gamma0, processed to the GEE...        SAR
# 80  Sentinel-1A/B SAR Gamma0, processed to the GEE...        SAR
# 89  Sentinel-1A/B SAR Gamma0, processed to the Yea...        SAR
# 13            Terra Aster -- metre, UTM 36 projection      ASTER
# 66            Terra Aster -- metre, UTM 36 projection      ASTER
#
#    creation_time    platform label   lat  time   lon product_type  format  \
# id
# 91          None      ALOS-2  None  None  None  None         tile  NetCDF
# 92          None      ALOS-2  None  None  None  None         tile  NetCDF
# 93          None      ALOS-2  None  None  None  None         tile  NetCDF
# 61          None      ALOS_2  None  None  None  None         tile  NetCDF
# 65          None      ALOS_2  None  None  None  None         tile  NetCDF
# 50          None      ALOS_2  None  None  None  None       gamma0  NetCDF
# 51          None      ALOS_2  None  None  None  None       gamma0  NetCDF
# 52          None      ALOS_2  None  None  None  None       gamma0  NetCDF
# 53          None        ALOS  None  None  None  None       gamma0  NetCDF
# 54          None        ALOS  None  None  None  None       gamma0  NetCDF
# 55          None        ALOS  None  None  None  None       gamma0  NetCDF
# 14          None         GPM  None  None  None  None        daily  NetCDF
# 15          None         GPM  None  None  None  None      monthly  NetCDF
# 17          None   LANDSAT_5  None  None  None  None       LEDAPS  NetCDF
# 18          None   LANDSAT_5  None  None  None  None       LEDAPS  NetCDF
# 85          None   LANDSAT_5  None  None  None  None       LEDAPS  NetCDF
# 19          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 20          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 35          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 87          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 21          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 22          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 74          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 23          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 41          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 24          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 25          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 26          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 27          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 28          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 68          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 75          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 82          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 79          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 29          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 30          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 31          None   LANDSAT_7  None  None  None  None       LEDAPS  NetCDF
# 86          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 73          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 32          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 33          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 70          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 83          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 77          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 71          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 40          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 34          None   LANDSAT_8  None  None  None  None        LaSRC  NetCDF
# 57          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 58          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 59          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 60          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 97          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 99          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 80          None  SENTINEL_1  None  None  None  None       gamma0  NetCDF
# 89          None   SENTINEL1  None  None  None  None      gamma_0  NetCDF
# 13          None       TERRA  None  None  None  None      GDEM_V2  NetCDF
# 66          None       TERRA  None  None  None  None      GDEM_V2  NetCDF
#
#           crs                                     resolution  \
# id
# 91  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 92  EPSG:4326  [-0.000226039783001808, 0.000231481481481481]
# 93  EPSG:4326   [-0.00022583559168925, 0.000241312741312741]
# 61  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 65  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 50  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 51  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 52  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 53  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 54  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 55  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 14  EPSG:4326                                    [-0.1, 0.1]
# 15  EPSG:4326                                    [-0.1, 0.1]
# 17  EPSG:4326                    [-0.000270861, 0.000294834]
# 18  EPSG:4326                     [-0.000271152, 0.00027769]
# 85  EPSG:4326                    [-0.000269493, 0.000269493]
# 19  EPSG:4326                    [-0.000271302, 0.000269995]
# 20  EPSG:4326                    [-0.000270861, 0.000294834]
# 35  EPSG:4326                    [-0.000270861, 0.000294834]
# 87  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 21  EPSG:4326                    [-0.000271307, 0.000269505]
# 22  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 74  EPSG:4326  [-0.000271141072802191, 0.000278249126645553]
# 23  EPSG:4326                    [-0.000269493, 0.000269493]
# 41  EPSG:4326                    [-0.000269493, 0.000269493]
# 24  EPSG:4326                     [-0.000271152, 0.00027769]
# 25  EPSG:4326                    [-0.000271297, 0.000270148]
# 26  EPSG:4326                    [-0.000270523, 0.000319227]
# 27  EPSG:4326                [-0.00027129679, 0.00027014858]
# 28  EPSG:4326                    [-0.000271285, 0.000270849]
# 68  EPSG:4326                    [-0.000270961, 0.000280452]
# 75  EPSG:4326                    [-0.000270676, 0.000307499]
# 82  EPSG:4326                    [-0.000269493, 0.000269493]
# 79  EPSG:4326  [-0.000269856975802825, 0.000394197414064964]
# 29  EPSG:4326                    [-0.000271285, 0.000270971]
# 30  EPSG:4326                    [-0.000270961, 0.000280452]
# 31  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 86  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 73  EPSG:4326  [-0.000271141072802191, 0.000278249126645553]
# 32  EPSG:4326                     [-0.000271152, 0.00027769]
# 33  EPSG:4326                [-0.00027129679, 0.00027014858]
# 70  EPSG:4326                    [-0.000270961, 0.000280452]
# 83  EPSG:4326                    [-0.000269493, 0.000269493]
# 77  EPSG:4326  [-0.000269856975802825, 0.000394197414064964]
# 71  EPSG:4326                    [-0.000270961, 0.000280452]
# 40  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 34  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 57  EPSG:4326              [-0.000269715032, 0.000269715032]
# 58  EPSG:4326              [-0.000269715032, 0.000269715032]
# 59  EPSG:4326              [-0.000269715032, 0.000269715032]
# 60  EPSG:4326              [-0.000269715032, 0.000269715032]
# 97  EPSG:4326  [-0.000180831826401447, 0.000179533213644524]
# 99  EPSG:4326  [-0.000180831826401447, 0.000184842883548983]
# 80  EPSG:4326                    [-0.000269493, 0.000269493]
# 89  EPSG:4326  [-0.000180831826401447, 0.000180831826401447]
# 13  EPSG:4326                    [-0.000271285, 0.000270849]
# 66  EPSG:4326                    [-0.000271285, 0.000270849]
#
#                                  tile_size     spatial_dimensions
# id
# 91            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 92                                  [1, 1]  (latitude, longitude)
# 93                                  [1, 1]  (latitude, longitude)
# 61            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 65            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 50            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 51            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 52            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 53            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 54            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 55            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 14                               [90, 180]  (latitude, longitude)
# 15                               [90, 180]  (latitude, longitude)
# 17                    [0.812583, 0.884502]  (latitude, longitude)
# 18                     [0.813456, 0.83307]  (latitude, longitude)
# 85                [0.99981903, 0.99981903]  (latitude, longitude)
# 19                    [0.813906, 0.809985]  (latitude, longitude)
# 20                    [0.812583, 0.884502]  (latitude, longitude)
# 35                    [0.812583, 0.884502]  (latitude, longitude)
# 87        [0.538989170472, 0.538989170472]  (latitude, longitude)
# 21                  [0.9495745, 0.9432675]  (latitude, longitude)
# 22        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 74  [0.999968276494482, 0.999470862910829]  (latitude, longitude)
# 23                [0.99981903, 0.99981903]  (latitude, longitude)
# 41              [0.249820011, 0.249820011]  (latitude, longitude)
# 24                     [0.813456, 0.83307]  (latitude, longitude)
# 25                    [0.813891, 0.810444]  (latitude, longitude)
# 26                  [0.9468305, 1.1172945]  (latitude, longitude)
# 27            [0.49999998397, 0.499774873]  (latitude, longitude)
# 28                  [0.9494975, 0.9479715]  (latitude, longitude)
# 68                    [0.812883, 0.841356]  (latitude, longitude)
# 75              [0.999877144, 0.999986748]  (latitude, longitude)
# 82                [0.99981903, 0.99981903]  (latitude, longitude)
# 79  [0.999550238373662, 0.999684642068748]  (latitude, longitude)
# 29                    [0.813855, 0.812913]  (latitude, longitude)
# 30                    [0.812883, 0.841356]  (latitude, longitude)
# 31        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 86        [0.538989170472, 0.538989170472]  (latitude, longitude)
# 73  [0.999968276494482, 0.999470862910829]  (latitude, longitude)
# 32                     [0.813456, 0.83307]  (latitude, longitude)
# 33            [0.49999998397, 0.499774873]  (latitude, longitude)
# 70                    [0.812883, 0.841356]  (latitude, longitude)
# 83                [0.99981903, 0.99981903]  (latitude, longitude)
# 77  [0.999550238373662, 0.999684642068748]  (latitude, longitude)
# 71                    [0.812883, 0.841356]  (latitude, longitude)
# 40        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 34        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 57              [0.809145096, 0.809145096]  (latitude, longitude)
# 58              [0.809145096, 0.809145096]  (latitude, longitude)
# 59              [0.809145096, 0.809145096]  (latitude, longitude)
# 60              [0.809145096, 0.809145096]  (latitude, longitude)
# 97                                  [1, 1]  (latitude, longitude)
# 99                                  [1, 1]  (latitude, longitude)
# 80                [0.99981903, 0.99981903]  (latitude, longitude)
# 89                                  [1, 1]  (latitude, longitude)
# 13                  [0.9494975, 0.9479715]  (latitude, longitude)
# 66                  [0.9494975, 0.9479715]  (latitude, longitude)

# %% [markdown]
# >### Pick a product
# >Use the platform and product names from the previous block to select a Data Cube.

# %%
import utils.data_cube_utilities.data_access_api as dc_api  
api = dc_api.DataAccessApi(config = '/home/localuser/.datacube.conf')

# Change the data platform and data cube here

platform = "LANDSAT_7"
# platform = "LANDSAT_8"

# product = "ls7_ledaps_ghana"
# product = "ls7_ledaps_kenya"
# product = "ls7_ledaps_senegal"
# product = "ls7_ledaps_sierra_leone"
# product = "ls7_ledaps_tanzania"
product = "ls7_ledaps_vietnam"

# Get Coordinates
coordinates = api.get_full_dataset_extent(platform = platform, product = product)

# %% [markdown]
# > #### Display Latitude-Longitude and Time Bounds of the Data Cube

# %%
latitude_extents = (min(coordinates['latitude'].values),max(coordinates['latitude'].values))
print( latitude_extents )
# Out:
# (9.176425374578418, 13.964805165051667)

# %%
longitude_extents = (min(coordinates['longitude'].values),max(coordinates['longitude'].values))
print( longitude_extents )
# Out:
# (102.40430421277932, 108.93092407802477)

# %%
time_extents = (min(coordinates['time'].values),max(coordinates['time'].values))
print( time_extents )
# Out:
# (numpy.datetime64('1999-09-08T03:13:19.000000000'), numpy.datetime64('2016-12-29T03:10:00.000000000'))

# %% [markdown]
# # Visualize Data Cube Region

# %%
## The code below renders a map that can be used to orient yourself with the region.
from utils.data_cube_utilities.dc_display_map import display_map
display_map(latitude = latitude_extents, longitude = longitude_extents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > ### Pick a smaller analysis region and display that region
# Try to keep your region to less than 0.02-deg x 0.02-deg for rapid processing. This will give you a region of about 75x75 pixels. You can click on the map above to find the Lat-Lon coordinates of any location. You will want to identify a region with an urban aree or some known vegetation. Pick a time window of 10+ years, as the curvefit algorithm requires a long time series to detect change.
# <br><br>
# Here is what to expect ... 0.02-deg x 0.02-deg (75x75 pixels) over 10 years will take 10 to 15 minutes to execute. Be patient ...

# %%
# Lam Dong Province near reservior 
# latitude_extents =  (11.843, 11.922)
# longitude_extents =  (107.723, 107.821)

latitude_extents =  (11.90, 11.92)
longitude_extents =  (107.76, 107.78)

time_extents = ('2001-01-01', '2010-01-01')
print ( time_extents )
# Out:
# ('2001-01-01', '2010-01-01')

# %%
display_map(latitude = latitude_extents, longitude = longitude_extents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Load the dataset and the required spectral bands or other parameters
# After loading, you will view the Xarray dataset. Notice the dimensions represent the number of pixels in your latitude and longitude dimension as well as the number of time slices (time) in your time series.

# %%
from utils.data_cube_utilities.dc_load import load_simple

# Reduce the resolution of the data to reduce memory consumption and run time.
landsat_dataset, clean_mask, masks = \
    load_simple(dc, platform = platform, product=product, frac_res=0.1,
                load_params=dict(latitude = latitude_extents,
                                 longitude = longitude_extents,
                                 platform = platform,
                                 time = time_extents,
                                 product = product,
                                 measurements = ['red', 'green', 'blue', 'nir', 'swir1', 'swir2', 'pixel_qa']))
del clean_mask, masks

# %%
landsat_dataset
#view the dimensions and sample content from the cube
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 24, longitude: 24, time: 93)
# Coordinates:
#   * latitude   (latitude) float64 11.92 11.92 11.92 11.92 ... 11.9 11.9 11.9
#   * longitude  (longitude) float64 107.8 107.8 107.8 107.8 ... 107.8 107.8 107.8
#   * time       (time) datetime64[ns] 2001-01-02T02:58:02 ... 2009-12-26T02:58:51
# Data variables:
#     red        (time, latitude, longitude) int16 476 434 369 369 ... 249 349 350
#     green      (time, latitude, longitude) int16 733 615 473 473 ... 337 402 533
#     blue       (time, latitude, longitude) int16 361 383 361 361 ... 254 295 275
#     nir        (time, latitude, longitude) int16 4688 4159 2511 ... 3277 3853
#     swir1      (time, latitude, longitude) int16 2160 1972 1217 ... 1325 1807
#     swir2      (time, latitude, longitude) int16 889 861 608 608 ... 358 529 757
#     pixel_qa   (time, latitude, longitude) int32 66 66 66 66 66 ... 66 66 66 66
# Attributes:
#     crs:      EPSG:4326

# %% [markdown]
# ## PyCCD
# The compute time of PyCCD scales sharply with extent sizes. Seemingly small areas can take anywhere from 10-15 minutes to process.

# %%
import utils.data_cube_utilities.dc_ccd as ccd

# %%
# %time change_matrix = ccd.process_xarray(landsat_dataset, distributed = True, process = "matrix") #Run process xarray on large dataset
# Out:
# CPU times: user 2.24 s, sys: 42.4 ms, total: 2.28 s
# Wall time: 1min 17s

# %%
# %time change_volume = (change_matrix.sum(dim='time') - 1).rename('change_volume')
# Out:
# CPU times: user 755 µs, sys: 0 ns, total: 755 µs
# Wall time: 531 µs

# %% [markdown]
# ## Plotting change volume
# Plot change volume to identify regions/areas of change. The change volume represents the number of land changes for a pixel over the time series.

# %%
import matplotlib.pyplot as plt  
from utils.data_cube_utilities.plotter_utils import figure_ratio

plt.figure(figsize = figure_ratio(change_volume))
change_volume.plot()
plt.axes().set_aspect("equal")

# %% [markdown]
# ## Plot the time of first changes

# %%
# %time
time_map_ccd_product = ccd._nth_occurence_in_ccd_matrix(change_matrix, 1, f = ccd._n64_datetime_to_scalar)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.34 µs

# %%
import datetime
from matplotlib.ticker import FuncFormatter

plt.figure(figsize = figure_ratio(time_map_ccd_product))
epochFormatter = FuncFormatter(lambda x, pos: datetime.datetime.utcfromtimestamp(x).strftime('%Y-%m-%d'))
time_map_ccd_product.plot(cmap = "magma", cbar_kwargs=({'format': epochFormatter}))
plt.axes().set_aspect("equal")

# %% [markdown]
# ## Validating Change
# Use the two images below to review scenes at the beginning of the time series and the end of the time series.

# %% [markdown]
# ### Review of RGB images
# Choose an image from the start and end of the time series. Remember that 0 is the first acquisition and the last acquisition if the number of time steps. You can find that number in the XARRAY report above. Try various combinations of the start and end images to identify the land changes using visual interpretation. You will see some images will have clouds and others will have Landsat-7 "bands". You can also change the RGB image bands to give you an combination you desire.

# %%
from utils.data_cube_utilities.dc_rgb import rgb

first = 2 # Acquisition Number ... change here

print( landsat_dataset.time.values[first] )

rgb( landsat_dataset,
     at_index = first,
     bands = ['swir2','nir','green'])
# Out:
# 2001-04-08T02:57:43.000000000
# (<Figure size 720x185.806 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7efee3b2f198>)

# %%
last = 50 # Acquisition Number ... change here

print( landsat_dataset.time.values[last] )

rgb(landsat_dataset,
    at_index = last,
    bands = ['swir2','nir','green'])
# Out:
# 2005-03-02T02:57:20.000000000
# (<Figure size 720x185.806 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7efee3ae8dd8>)

# %% [markdown]
# # Vogelmann NDVI Trend

# %%
import utils.data_cube_utilities.trend as trend

# %%
import numpy as np

def land_and_water_masking_ls7(dataset):    
    #Create boolean Masks for clear and water pixels
    clear_pixels = dataset.pixel_qa.values == 2 + 64
    water_pixels = dataset.pixel_qa.values == 4 + 64

    a_clean_mask = np.logical_or(clear_pixels, water_pixels)
    return a_clean_mask

# %%
def remove_clouds(dataset):  
    return dataset.where(land_and_water_masking_ls7(dataset)).drop('pixel_qa')

# %%
def NDVI(dataset):
    return (dataset.nir - dataset.red)/(dataset.nir + dataset.red)

# %%
ndvi_trend_product = trend.linear(NDVI(remove_clouds(landsat_dataset)))

# %%
(-ndvi_trend_product).plot()
