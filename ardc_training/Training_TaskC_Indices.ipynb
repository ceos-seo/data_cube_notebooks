# %%
from sys import path
path.append("../")

# %% [markdown]
# # ARDC Training: Python Notebooks
# Task-C: Fractional Cover (FC) and Spectral Indices (NDBI and NDVI)

# %% [markdown]
# > ### Import the Datacube Configuration

# %%
import datacube
dc = datacube.Datacube(app = 'my_app', config = '/home/localuser/.datacube.conf')

# %%
# Supress Warning 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# >### Browse the available Data Cubes

# %%
list_of_products = dc.list_products()
netCDF_products = list_of_products[list_of_products['format'] == 'NetCDF']
netCDF_products
# Out:
#                                   name  \
# id
# 91    alos02_palsar02_scansar_colombia
# 92       alos02_palsar02_scansar_samoa
# 93     alos02_palsar02_scansar_vietnam
# 61  alos2_jjfast_scansar_tile_colombia
# 65       alos2_palsar2_scansar_caqueta
# 50               alos2_palsar_colombia
# 51                  alos2_palsar_kenya
# 52                alos2_palsar_vietnam
# 53                alos_palsar_colombia
# 54                   alos_palsar_kenya
# 55                 alos_palsar_vietnam
# 14          gpm_imerg_gis_daily_global
# 15        gpm_imerg_gis_monthly_global
# 17               ls5_ledaps_bangladesh
# 18           ls5_ledaps_lake_chad_full
# 85               ls5_ledaps_swiss_mini
# 19             ls7_ledaps_amazon_river
# 20               ls7_ledaps_bangladesh
# 35          ls7_ledaps_bangladesh_bari
# 87                  ls7_ledaps_caqueta
# 21                 ls7_ledaps_colombia
# 22                    ls7_ledaps_ghana
# 74                 ls7_ledaps_honduras
# 23                    ls7_ledaps_kenya
# 41             ls7_ledaps_lake_baringo
# 24           ls7_ledaps_lake_chad_full
# 25             ls7_ledaps_lake_cortijo
# 26           ls7_ledaps_menindee_lakes
# 27               ls7_ledaps_meta_river
# 28          ls7_ledaps_salgar_colombia
# 68                    ls7_ledaps_samoa
# 75             ls7_ledaps_south_africa
# 82               ls7_ledaps_swiss_mini
# 79              ls7_ledaps_switzerland
# 29                     ls7_ledaps_togo
# 30                    ls7_ledaps_tonga
# 31                  ls7_ledaps_vietnam
# 86                   ls8_lasrc_caqueta
# 73                  ls8_lasrc_honduras
# 32            ls8_lasrc_lake_chad_full
# 33                ls8_lasrc_meta_river
# 70                     ls8_lasrc_samoa
# 83                ls8_lasrc_swiss_mini
# 77               ls8_lasrc_switzerland
# 71                     ls8_lasrc_tonga
# 40                   ls8_lasrc_uruguay
# 34                   ls8_lasrc_vietnam
# 57                  s1_gamma0_colombia
# 58                 s1_gamma0_lake_chad
# 59            s1_gamma0_menindee_lakes
# 60                   s1_gamma0_vietnam
# 97                  s1g_gamma0_caqueta
# 99                    s1g_gamma0_samoa
# 80              s1g_gamma0_switzerland
# 89               s1yearly_gamma0_ghana
# 13     terra_aster_gdm_salgar_colombia
# 66               terra_aster_gdm_samoa
#
#                                           description   lat instrument  \
# id
# 91  ALOS2 PALSAR JJFAST tile in DN format processe...  None   PALSAR-2
# 92  ALOS2 PALSAR JJFAST tile in DN format processe...  None   PALSAR-2
# 93  ALOS2 PALSAR JJFAST tile in DN format processe...  None   PALSAR-2
# 61  ALOS2 PALSAR JJFAST tile in DN format processe...  None     PALSAR
# 65  ALOS2 PALSAR JJFAST tile in DN format processe...  None   PALSAR_2
# 50  ALOS2 PALSAR tile in DN format processed for t...  None     PALSAR
# 51  ALOS2 PALSAR tile in DN format processed for t...  None     PALSAR
# 52  ALOS2 PALSAR tile in DN format processed for t...  None     PALSAR
# 53  ALOS PALSAR tile in DN format processed for th...  None     PALSAR
# 54  ALOS PALSAR tile in DN format processed for th...  None     PALSAR
# 55  ALOS PALSAR tile in DN format processed for th...  None     PALSAR
# 14                   Global NetCDF GPM IMERG GIS data  None        GPM
# 15                   Global NetCDF GPM IMERG GIS data  None        GPM
# 17  Landsat 5 USGS Collection 1 Higher Level SR sc...  None         TM
# 18  Landsat 5 USGS Collection 1 Higher Level SR sc...  None         TM
# 85  Landsat 5 USGS Collection 1 Higher Level SR sc...  None        TM1
# 19  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 20  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 35  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 87  Landsat 7 USGS Collection 1 Higher Level SR sc...  None       ETM1
# 21  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 22  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 74  Landsat 7 USGS Collection 1 Higher Level SR sc...  None       ETM1
# 23  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 41  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 24  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 25  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 26  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 27  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 28  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 68  Landsat 7 USGS Collection 1 Higher Level SR sc...  None       ETM1
# 75  Landsat 7 USGS Collection 1 Higher Level SR sc...  None       ETM1
# 82  Landsat 7 USGS Collection 1 Higher Level SR sc...  None       ETM3
# 79  Landsat 7 USGS Collection 1 Higher Level SR sc...  None       ETM3
# 29  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 30  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 31  Landsat 7 USGS Collection 1 Higher Level SR sc...  None        ETM
# 86  Landsat 8 USGS Collection 1 Higher Level SR sc...  None  OLI_TIRS1
# 73  Landsat 8 USGS Collection 1 Higher Level SR sc...  None  OLI_TIRS1
# 32  Landsat 8 USGS Collection 1 Higher Level SR sc...  None   OLI_TIRS
# 33  Landsat 8 USGS Collection 1 Higher Level SR sc...  None   OLI_TIRS
# 70  Landsat 8 USGS Collection 1 Higher Level SR sc...  None  OLI_TIRS1
# 83  Landsat 8 USGS Collection 1 Higher Level SR sc...  None  OLI_TIRS1
# 77  Landsat 8 USGS Collection 1 Higher Level SR sc...  None  OLI_TIRS1
# 71  Landsat 8 USGS Collection 1 Higher Level SR sc...  None  OLI_TIRS1
# 40  Landsat 8 USGS Collection 1 Higher Level SR sc...  None   OLI_TIRS
# 34  Landsat 8 USGS Collection 1 Higher Level SR sc...  None   OLI_TIRS
# 57  Sentinel-1A/B SAR Gamma0, processed to the CEO...  None        SAR
# 58  Sentinel-1A/B SAR Gamma0, processed to the CEO...  None        SAR
# 59  Sentinel-1A/B SAR Gamma0, processed to the CEO...  None        SAR
# 60  Sentinel-1A/B SAR Gamma0, processed to the CEO...  None        SAR
# 97  Sentinel-1A/B SAR Gamma0, processed to the GEE...  None        SAR
# 99  Sentinel-1A/B SAR Gamma0, processed to the GEE...  None        SAR
# 80  Sentinel-1A/B SAR Gamma0, processed to the GEE...  None        SAR
# 89  Sentinel-1A/B SAR Gamma0, processed to the Yea...  None        SAR
# 13            Terra Aster -- metre, UTM 36 projection  None      ASTER
# 66            Terra Aster -- metre, UTM 36 projection  None      ASTER
#
#     format  time product_type creation_time   lon label    platform  \
# id
# 91  NetCDF  None         tile          None  None  None      ALOS-2
# 92  NetCDF  None         tile          None  None  None      ALOS-2
# 93  NetCDF  None         tile          None  None  None      ALOS-2
# 61  NetCDF  None         tile          None  None  None      ALOS_2
# 65  NetCDF  None         tile          None  None  None      ALOS_2
# 50  NetCDF  None       gamma0          None  None  None      ALOS_2
# 51  NetCDF  None       gamma0          None  None  None      ALOS_2
# 52  NetCDF  None       gamma0          None  None  None      ALOS_2
# 53  NetCDF  None       gamma0          None  None  None        ALOS
# 54  NetCDF  None       gamma0          None  None  None        ALOS
# 55  NetCDF  None       gamma0          None  None  None        ALOS
# 14  NetCDF  None        daily          None  None  None         GPM
# 15  NetCDF  None      monthly          None  None  None         GPM
# 17  NetCDF  None       LEDAPS          None  None  None   LANDSAT_5
# 18  NetCDF  None       LEDAPS          None  None  None   LANDSAT_5
# 85  NetCDF  None       LEDAPS          None  None  None   LANDSAT_5
# 19  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 20  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 35  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 87  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 21  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 22  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 74  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 23  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 41  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 24  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 25  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 26  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 27  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 28  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 68  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 75  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 82  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 79  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 29  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 30  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 31  NetCDF  None       LEDAPS          None  None  None   LANDSAT_7
# 86  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 73  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 32  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 33  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 70  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 83  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 77  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 71  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 40  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 34  NetCDF  None        LaSRC          None  None  None   LANDSAT_8
# 57  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 58  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 59  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 60  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 97  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 99  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 80  NetCDF  None       gamma0          None  None  None  SENTINEL_1
# 89  NetCDF  None      gamma_0          None  None  None   SENTINEL1
# 13  NetCDF  None      GDEM_V2          None  None  None       TERRA
# 66  NetCDF  None      GDEM_V2          None  None  None       TERRA
#
#           crs                                     resolution  \
# id
# 91  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 92  EPSG:4326  [-0.000226039783001808, 0.000231481481481481]
# 93  EPSG:4326   [-0.00022583559168925, 0.000241312741312741]
# 61  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 65  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 50  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 51  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 52  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 53  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 54  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 55  EPSG:4326            [-0.0002666666667, 0.0002666666667]
# 14  EPSG:4326                                    [-0.1, 0.1]
# 15  EPSG:4326                                    [-0.1, 0.1]
# 17  EPSG:4326                    [-0.000270861, 0.000294834]
# 18  EPSG:4326                     [-0.000271152, 0.00027769]
# 85  EPSG:4326                    [-0.000269493, 0.000269493]
# 19  EPSG:4326                    [-0.000271302, 0.000269995]
# 20  EPSG:4326                    [-0.000270861, 0.000294834]
# 35  EPSG:4326                    [-0.000270861, 0.000294834]
# 87  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 21  EPSG:4326                    [-0.000271307, 0.000269505]
# 22  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 74  EPSG:4326  [-0.000271141072802191, 0.000278249126645553]
# 23  EPSG:4326                    [-0.000269493, 0.000269493]
# 41  EPSG:4326                    [-0.000269493, 0.000269493]
# 24  EPSG:4326                     [-0.000271152, 0.00027769]
# 25  EPSG:4326                    [-0.000271297, 0.000270148]
# 26  EPSG:4326                    [-0.000270523, 0.000319227]
# 27  EPSG:4326                [-0.00027129679, 0.00027014858]
# 28  EPSG:4326                    [-0.000271285, 0.000270849]
# 68  EPSG:4326                    [-0.000270961, 0.000280452]
# 75  EPSG:4326                    [-0.000270676, 0.000307499]
# 82  EPSG:4326                    [-0.000269493, 0.000269493]
# 79  EPSG:4326  [-0.000269856975802825, 0.000394197414064964]
# 29  EPSG:4326                    [-0.000271285, 0.000270971]
# 30  EPSG:4326                    [-0.000270961, 0.000280452]
# 31  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 86  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 73  EPSG:4326  [-0.000271141072802191, 0.000278249126645553]
# 32  EPSG:4326                     [-0.000271152, 0.00027769]
# 33  EPSG:4326                [-0.00027129679, 0.00027014858]
# 70  EPSG:4326                    [-0.000270961, 0.000280452]
# 83  EPSG:4326                    [-0.000269493, 0.000269493]
# 77  EPSG:4326  [-0.000269856975802825, 0.000394197414064964]
# 71  EPSG:4326                    [-0.000270961, 0.000280452]
# 40  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 34  EPSG:4326        [-0.000269494585236, 0.000269494585236]
# 57  EPSG:4326              [-0.000269715032, 0.000269715032]
# 58  EPSG:4326              [-0.000269715032, 0.000269715032]
# 59  EPSG:4326              [-0.000269715032, 0.000269715032]
# 60  EPSG:4326              [-0.000269715032, 0.000269715032]
# 97  EPSG:4326  [-0.000180831826401447, 0.000179533213644524]
# 99  EPSG:4326  [-0.000180831826401447, 0.000184842883548983]
# 80  EPSG:4326                    [-0.000269493, 0.000269493]
# 89  EPSG:4326  [-0.000180831826401447, 0.000180831826401447]
# 13  EPSG:4326                    [-0.000271285, 0.000270849]
# 66  EPSG:4326                    [-0.000271285, 0.000270849]
#
#                                  tile_size     spatial_dimensions
# id
# 91            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 92                                  [1, 1]  (latitude, longitude)
# 93                                  [1, 1]  (latitude, longitude)
# 61            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 65            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 50            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 51            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 52            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 53            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 54            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 55            [0.5333333334, 0.5333333334]  (latitude, longitude)
# 14                               [90, 180]  (latitude, longitude)
# 15                               [90, 180]  (latitude, longitude)
# 17                    [0.812583, 0.884502]  (latitude, longitude)
# 18                     [0.813456, 0.83307]  (latitude, longitude)
# 85                [0.99981903, 0.99981903]  (latitude, longitude)
# 19                    [0.813906, 0.809985]  (latitude, longitude)
# 20                    [0.812583, 0.884502]  (latitude, longitude)
# 35                    [0.812583, 0.884502]  (latitude, longitude)
# 87        [0.538989170472, 0.538989170472]  (latitude, longitude)
# 21                  [0.9495745, 0.9432675]  (latitude, longitude)
# 22        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 74  [0.999968276494482, 0.999470862910829]  (latitude, longitude)
# 23                [0.99981903, 0.99981903]  (latitude, longitude)
# 41              [0.249820011, 0.249820011]  (latitude, longitude)
# 24                     [0.813456, 0.83307]  (latitude, longitude)
# 25                    [0.813891, 0.810444]  (latitude, longitude)
# 26                  [0.9468305, 1.1172945]  (latitude, longitude)
# 27            [0.49999998397, 0.499774873]  (latitude, longitude)
# 28                  [0.9494975, 0.9479715]  (latitude, longitude)
# 68                    [0.812883, 0.841356]  (latitude, longitude)
# 75              [0.999877144, 0.999986748]  (latitude, longitude)
# 82                [0.99981903, 0.99981903]  (latitude, longitude)
# 79  [0.999550238373662, 0.999684642068748]  (latitude, longitude)
# 29                    [0.813855, 0.812913]  (latitude, longitude)
# 30                    [0.812883, 0.841356]  (latitude, longitude)
# 31        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 86        [0.538989170472, 0.538989170472]  (latitude, longitude)
# 73  [0.999968276494482, 0.999470862910829]  (latitude, longitude)
# 32                     [0.813456, 0.83307]  (latitude, longitude)
# 33            [0.49999998397, 0.499774873]  (latitude, longitude)
# 70                    [0.812883, 0.841356]  (latitude, longitude)
# 83                [0.99981903, 0.99981903]  (latitude, longitude)
# 77  [0.999550238373662, 0.999684642068748]  (latitude, longitude)
# 71                    [0.812883, 0.841356]  (latitude, longitude)
# 40        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 34        [0.943231048326, 0.943231048326]  (latitude, longitude)
# 57              [0.809145096, 0.809145096]  (latitude, longitude)
# 58              [0.809145096, 0.809145096]  (latitude, longitude)
# 59              [0.809145096, 0.809145096]  (latitude, longitude)
# 60              [0.809145096, 0.809145096]  (latitude, longitude)
# 97                                  [1, 1]  (latitude, longitude)
# 99                                  [1, 1]  (latitude, longitude)
# 80                [0.99981903, 0.99981903]  (latitude, longitude)
# 89                                  [1, 1]  (latitude, longitude)
# 13                  [0.9494975, 0.9479715]  (latitude, longitude)
# 66                  [0.9494975, 0.9479715]  (latitude, longitude)

# %% [markdown]
# >### Pick a product
# >Use the platform and product names from the previous block to select a Data Cube.

# %%
import utils.data_cube_utilities.data_access_api as dc_api  
api = dc_api.DataAccessApi(config = '/home/localuser/.datacube.conf')

# Change the data platform and data cube here

platform = "LANDSAT_7"
# platform = "LANDSAT_8"

# product = "ls7_ledaps_ghana"
# product = "ls7_ledaps_kenya"
# product = "ls7_ledaps_senegal"
# product = "ls7_ledaps_sierra_leone"
# product = "ls7_ledaps_tanzania"
product = "ls7_ledaps_vietnam" 

# Get Coordinates
coordinates = api.get_full_dataset_extent(platform = platform, product = product)

# %% [markdown]
# > #### Display Latitude-Longitude and Time Bounds of the Data Cube

# %%
latitude_extents = (min(coordinates['latitude'].values),max(coordinates['latitude'].values))
print( latitude_extents )
# Out:
# (9.176425374578418, 13.964805165051667)

# %%
longitude_extents = (min(coordinates['longitude'].values),max(coordinates['longitude'].values))
print( longitude_extents )
# Out:
# (102.40430421277932, 108.93092407802477)

# %%
time_extents = (min(coordinates['time'].values),max(coordinates['time'].values))
print( time_extents )
# Out:
# (numpy.datetime64('1999-09-08T03:13:19.000000000'), numpy.datetime64('2016-12-29T03:10:00.000000000'))

# %% [markdown]
# # Visualize Data Cube Region

# %%
## The code below renders a map that can be used to orient yourself with the region.
from utils.data_cube_utilities.dc_display_map import display_map
display_map(latitude = latitude_extents, longitude = longitude_extents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > ### Pick a smaller analysis region and display that region
# Try to keep your region to less than 0.2-deg x 0.2-deg for rapid processing. You can click on the map above to find the Lat-Lon coordinates of any location. You will want to identify a region with an urban aree or some known vegetation. Pick a time window of a few months to a year so we can pick out some clear pixels.

# %%
## Vietnam - Central Lam Dong Province ##
longitude_extents = (105.2, 105.5)
latitude_extents  = (11.25, 11.55)

time_extents = ('2015-01-01', '2016-01-01')
print ( time_extents )
# Out:
# ('2015-01-01', '2016-01-01')

# %%
display_map(latitude = latitude_extents, longitude = longitude_extents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Load the dataset and the required spectral bands or other parameters
# After loading, you will view the Xarray dataset. Notice the dimensions represent the number of pixels in your latitude and longitude dimension as well as the number of time slices (time) in your time series.

# %%
landsat_dataset = dc.load(latitude = latitude_extents,
                          longitude = longitude_extents,
                          platform = platform,
                          time = time_extents,
                          product = product,
                          measurements = ['red', 'green', 'blue', 'nir', 'swir1', 'swir2', 'pixel_qa'])

# %%
landsat_dataset
#view the dimensions and sample content from the cube
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 1115, longitude: 1114, time: 16)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-07T03:18:35 ... 2015-12-25T03:21:19
#   * latitude   (latitude) float64 11.55 11.55 11.55 11.55 ... 11.25 11.25 11.25
#   * longitude  (longitude) float64 105.2 105.2 105.2 105.2 ... 105.5 105.5 105.5
# Data variables:
#     red        (time, latitude, longitude) int16 1392 1251 1190 ... -9999 -9999
#     green      (time, latitude, longitude) int16 1367 1257 1257 ... -9999 -9999
#     blue       (time, latitude, longitude) int16 1242 1158 1094 ... -9999 -9999
#     nir        (time, latitude, longitude) int16 2654 2700 2972 ... -9999 -9999
#     swir1      (time, latitude, longitude) int16 1550 1577 1818 ... -9999 -9999
#     swir2      (time, latitude, longitude) int16 923 952 980 ... -9999 -9999
#     pixel_qa   (time, latitude, longitude) int32 224 224 224 224 224 ... 1 1 1 1
# Attributes:
#     crs:      EPSG:4326

# %% [markdown]
# # Display Example Images
#
# >#### Single band visualization
# > For a quick inspection, let's look at one image. The code will allow the selection of any band (red, blue, green, nir, swir1, swir2) to produce a grey-scale image. Select the desired acquisition (time slice) in the block below. You can select from 1 to #, where the max value is the number of time slices noted in the block above. Change the comment statements below to select the bands for the first image.

# %%
acquisition_number = 0
# select an acquisition number from 0 (first time layer) to "time" using the array limits above

# %%
# %matplotlib inline
#landsat_dataset.red.isel(time = acquisition_number).plot(cmap = "Greys")
landsat_dataset.green.isel(time = acquisition_number).plot(cmap = "Greys")
#landsat_dataset.blue.isel(time = acquisition_number).plot(cmap = "Greys")
#landsat_dataset.nir.isel(time = acquisition_number).plot(cmap = "Greys")
#landsat_dataset.swir1.isel(time = acquisition_number).plot(cmap = "Greys")
#landsat_dataset.swir2.isel(time = acquisition_number).plot(cmap = "Greys")

# %% [markdown]
# >#### Define Cloud Masking Function
# Removes clouds and cloud shadows based on the Landsat pixel QA information
# This is only for reference ... nothing to modify here

# %%
import numpy as np  

def generate_cloud_mask(dataset, include_shadows = False):
    #Create boolean Masks for clear and water pixels
    clear_pixels = dataset.pixel_qa.values == 2  + 64
    water_pixels = dataset.pixel_qa.values == 4  + 64
    shadow_pixels= dataset.pixel_qa.values == 8 + 64
    
    a_clean_mask = np.logical_or(clear_pixels, water_pixels)
    
    if include_shadows:
        a_clean_mask = np.logical_or(a_clean_mask, shadow_pixels)
        
    return np.invert(a_clean_mask)

def remove_clouds(dataset, include_shadows = False):
    #Create boolean Masks for clear and water pixels
    clear_pixels = dataset.pixel_qa.values == 2  + 64
    water_pixels = dataset.pixel_qa.values == 4  + 64
    shadow_pixels= dataset.pixel_qa.values == 8 + 64
    
    a_clean_mask = np.logical_or(clear_pixels, water_pixels)
    
    if include_shadows:
        a_clean_mask = np.logical_or(a_clean_mask, shadow_pixels)
        
    return dataset.where(a_clean_mask)

# %%
cloud_mask = generate_cloud_mask(landsat_dataset)
cloudless = remove_clouds(landsat_dataset) #landsat_dataset.where(image_is_clean)

# %% [markdown]
# >Set up plotting function (to be used later)
# >Nothing to modify here

# %% [markdown]
# > **Median Mosaic**
# >  Masks clouds from imagery using the median valued cloud-free pixels in the time series

# %%
from utils.data_cube_utilities.dc_mosaic import create_median_mosaic

def median_mosaic(dataset):
    # The mask here is based on pixel_qa products. It comes bundled in with most Landsat Products.
    cloud_free_boolean_mask = np.invert(generate_cloud_mask(dataset))
    return create_median_mosaic(dataset, clean_mask = cloud_free_boolean_mask)

# %%
median_composite = median_mosaic(landsat_dataset)

# %%
median_composite.nir.plot(cmap = "Greys")

# %%
from utils.data_cube_utilities.dc_rgb import rgb
rgb(median_composite)
# Out:
# (<Figure size 720x719.354 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa5a0b32c18>)

# %% [markdown]
# # Fractional Cover
#
# Fractional Cover (FC) is used for landcover type estimation (vegetation, non-green vegetation, bare soil) of each pixel. We use a model from CSIRO (Juan Gerschmann) and apply it to a median mosaic.

# %%
from utils.data_cube_utilities.dc_fractional_coverage_classifier import frac_coverage_classify 
frac_classes = frac_coverage_classify(median_composite, clean_mask = np.ones(median_composite.pixel_qa.shape).astype(np.bool))

# %% [markdown]
# ## Plotting Fractional Cover Results
# Plot Bare Soil (bs), Photosynthetic Vegetation (pv) or Non Photosynthetic Vegetation (npv)
# <br>
# Plot a False Color RGB result where RGB = bs/pv/npv.

# %%
frac_classes.bs.plot(cmap = "Greys")
#frac_classes.pv.plot(cmap = "Greys")
#frac_classes.npv.plot(cmap = "Greys")

# %%
rgb(frac_classes, bands = ['bs', 'pv', 'npv'])
# Out:
# (<Figure size 720x719.354 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa5a0b10908>)

# %% [markdown]
# # Spectral Indices
# NDVI (vegetation) and NDBI (urbanization)

# %% [markdown]
# ### NDVI = Normalized Difference Vegetation Index
# A derived index that correlates well with the existance of vegetation.
#
# $$ NDVI =  \frac{(NIR - RED)}{(NIR + RED)}$$

# %%
def NDVI(dataset):
    return (dataset.nir - dataset.red)/(dataset.nir + dataset.red)

# %% [markdown]
# ### NDBI = Normalized Difference Build-Up Index
# A derived index that correlates well with the existance of urbanization.
# <br>
#
# $$NDBI =  \frac{(SWIR1 - NIR)}{(SWIR1 + NIR)}$$

# %%
def NDBI(dataset):
        return (dataset.swir1 - dataset.nir)/(dataset.swir1 + dataset.nir)

# %%
landsat_mosaic = median_mosaic(landsat_dataset)  

ndbi = NDBI(landsat_mosaic)  # Urbanization - Reds
ndvi_mosaic = NDVI(landsat_mosaic)  # Dense Vegetation - Greens

# %%
(ndbi).plot(cmap = "Reds")

# %%
(ndvi_mosaic).plot(cmap = "Greens")

# %% [markdown]
# ## Create a threshold plot
# First we will define a minimum threshold and a maximum threshold. Then you will create a plot that colors the region between the threshold a single color (e.g. red) and the region outside the threshold will be BLACK or WHITE. Also, we will calculate the % of pixels and the number of pixels in the threshold range.

# %%
# Select the time slice for the NVDI output (first slice=0)
t = 0
ndvi_dataset_at_time_t = NDVI(landsat_dataset).isel(time = t)  
mask_at_time_t = generate_cloud_mask(landsat_dataset.isel(time = t))

# %%
# Define the threshold region bounds
minimum_threshold = 0.6
maximum_threshold = 0.9

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt

def threshold_plot(da, min_threshold, max_threshold, mask = None, width = 10, *args, **kwargs): 
    color_in    = np.array([255,0,0])
    color_out   = np.array([0,0,0])
    color_cloud = np.array([255,255,255])
    
    array = np.zeros((*da.values.shape, 3)).astype(np.int16)
    
    inside  = np.logical_and(da.values > min_threshold, da.values < max_threshold)
    outside = np.invert(inside)
    masked  = np.zeros(da.values.shape).astype(bool) if mask is None else mask
    
    array[inside] =  color_in
    array[outside] = color_out
    array[masked] =  color_cloud

    def figure_ratio(ds, fixed_width = 10):
        width = fixed_width
        height = len(ds.latitude) * (fixed_width / len(ds.longitude))
        return (width, height)


    fig, ax = plt.subplots(figsize = figure_ratio(da,fixed_width = width))
    
    lat_formatter = FuncFormatter(lambda y_val, tick_pos: "{0:.3f}".format(da.latitude.values[tick_pos] ))
    lon_formatter = FuncFormatter(lambda x_val, tick_pos: "{0:.3f}".format(da.longitude.values[tick_pos]))

    ax.xaxis.set_major_formatter(lon_formatter)
    ax.yaxis.set_major_formatter(lat_formatter)
    
    plt.title("Threshold: {} < x < {}".format(min_threshold, max_threshold))
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    
    plt.imshow(array, *args, **kwargs)
    plt.show()

# %% [markdown]
# ### Plot NDVI Mosaic

# %%
# Plot the NDVI threshold product using a cloud-filterd mosaic
threshold_plot(ndvi_mosaic, minimum_threshold, maximum_threshold, width = 10)

# %% [markdown]
# ### Plot NDVI at time t

# %%
# Plot the NDVI threshold product using a single time slice (one scene)
threshold_plot(ndvi_dataset_at_time_t, minimum_threshold, maximum_threshold, width = 10, mask = mask_at_time_t,)

# %%
def threshold_count(da, min_threshold, max_threshold, mask = None):
    def count_not_nans(arr):
        return np.count_nonzero(~np.isnan(arr))
    
    in_threshold = np.logical_and( da.values > min_threshold, da.values < max_threshold)
    
    total_non_cloudy = count_not_nans(da.values) if mask is None else np.sum(mask) 
    
    return dict(total = np.size(da.values),
                total_non_cloudy = total_non_cloudy,
                inside = np.nansum(in_threshold),
                outside = total_non_cloudy - np.nansum(in_threshold)
               )    
    
def threshold_percentage(da, min_threshold, max_threshold, mask = None):
    counts = threshold_count(da, min_threshold, max_threshold, mask = mask)
    return dict(percent_inside_threshold = (counts["inside"]   / counts["total"]) * 100.0,
                percent_outside_threshold = (counts["outside"] / counts["total"]) * 100.0,
                percent_clouds = ( 100.0-counts["total_non_cloudy"] / counts["total"] * 100.0))

# %%
threshold_count(ndvi_mosaic,
                minimum_threshold,
                maximum_threshold)
# Out:
# {'total': 1242110,
#  'total_non_cloudy': 1242110,
#  'inside': 112330,
#  'outside': 1129780}

# %%
threshold_percentage(ndvi_mosaic,
                     minimum_threshold,
                     maximum_threshold)
# Out:
# {'percent_inside_threshold': 9.0434824612957,
#  'percent_outside_threshold': 90.9565175387043,
#  'percent_clouds': 0.0}

# %%
threshold_count(ndvi_dataset_at_time_t,
                minimum_threshold,
                maximum_threshold,
                mask = mask_at_time_t)
# Out:
# {'total': 1242110,
#  'total_non_cloudy': 828303,
#  'inside': 97721,
#  'outside': 730582}

# %%
threshold_percentage(ndvi_dataset_at_time_t,
                     minimum_threshold,
                     maximum_threshold,
                     mask = mask_at_time_t )
# Out:
# {'percent_inside_threshold': 7.867338641505181,
#  'percent_outside_threshold': 58.81781806764296,
#  'percent_clouds': 33.314843290851854}

# %% [markdown]
# ## Select a single pixel and plot an index value over time

# %%
pixel_lat = 11.45
pixel_lon = 105.40

# %%
pixel = NDVI(remove_clouds(landsat_dataset)).sel(latitude  = pixel_lat,
                                                longitude = pixel_lon,
                                                method = 'nearest') # nearest neighbor selection

# %%
plt.figure(figsize = (20,5)) 
plt.scatter(pixel.time.values, pixel.values)
