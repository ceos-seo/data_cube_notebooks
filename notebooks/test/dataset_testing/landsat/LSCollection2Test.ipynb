# %% [markdown]
# ## Connect to the datacube

# %%
import datacube
from datacube.utils.aws import configure_s3_access

configure_s3_access(requester_pays=True)
dc = datacube.Datacube()

# %%
dc.list_products()
# Out:
#          name                                        description  \
# id
# 1   ls8_l2_c2  Landsat 8 USGS Collection 1 Level2 Surface Ref...
#
#        product_type   platform   lat   format  time label instrument   lon  \
# id
# 1   LaSRCollection2  LANDSAT_8  None  GeoTiff  None  None   OLI_TIRS  None
#
#    creation_time        crs                             resolution tile_size  \
# id
# 1           None  EPSG:4326  (-0.00027777777778, 0.00027777777778)      None
#
#        spatial_dimensions
# id
# 1   (latitude, longitude)

# %% [markdown]
# ## Show the extents of the product

# %%
metadata = dc.load(product='ls8_l2_c2', measurements=[])

# %%
from utils.data_cube_utilities.dc_display_map import display_map

# %%
full_lon = metadata.longitude[[0, -1]].values
full_lat = metadata.latitude[[-1, 0]].values
display_map(full_lat, full_lon)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lon = (36.7905, 36.9461)
lat = (-1.3477, -1.2432)
display_map(lat, lon)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data = dc.load(product='ls8_l2_c2', lat=lat, lon=lon, time=("2014-01-01", "2014-12-31"),
               dask_chunks={'latitude': 2000, 'longitude': 2000, 'time':10}, 
               measurements=['red', 'green', 'blue'])

# %%
rgb = data[['red', 'green', 'blue']]

# %%
rgb_mean = rgb.mean('time').compute()

# %%
rgb_mean.to_array().plot.imshow(vmin=0, vmax=40000)
